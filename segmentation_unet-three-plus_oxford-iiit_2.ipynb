# %% [markdown]
# # Example: Image segmentation using customized UNET 3+ and hybrid loss

# %%
import tensorflow as tf
import numpy as np
from glob import glob
tf.__version__
# Out:
# '2.6.0'

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, Dropout, Activation, UpSampling2D, GlobalMaxPooling2D, multiply
from tensorflow.keras.backend import max

# %% [markdown]
# This example requires `keras-unet-collection==0.1.6` or higher:
# ```
# pip install keras-unet-collection
# ```

# %%
from keras_unet_collection import models, base, utils

# %%
# the indicator of a fresh run
first_time_running = False

# user-specified working directory
filepath = '/work/matteo/Documents/oxford_iiit/'

# %% [markdown]
# ## The Oxford-IIIT Pets dataset
#
# This example applies the dataset of [Oxford-IIIT Pet Dataset](https://www.robots.ox.ac.uk/~vgg/data/pets/) (Parkhi et al. 2012). This dataset contains images of pets and their pixel-wise mask that indicates (1) pixels belonging to the pet, (2) pixels bordering the pet, and (3) surrounding pixels.
#
# The Oxford-IIIT Pets dataset will be downloaded and unpacked through the cell blow.

# %%
if first_time_running:
    # downloading and executing data files
    import tarfile
    import urllib.request
    
    filename_image = filepath+'images.tar.gz'
    filename_target = filepath+'annotations.tar.gz'
    
    urllib.request.urlretrieve('http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz', filename_image);
    urllib.request.urlretrieve('https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz', filename_target);
    
    with tarfile.open(filename_image, "r:gz") as tar_io:
        tar_io.extractall(path=filepath)
    with tarfile.open(filename_target, "r:gz") as tar_io:
        tar_io.extractall(path=filepath)

# %% [markdown]
# ## Customizing a segmentation model based on UNET 3+
#
# In this example, an image segmentation model is proposed to classify the pixel mask by taking the re-sized RGB images as inputs.
#
# The architecture of UNET 3+ is applied in this segmentation task. UNET 3+ is a convolutional neural network with encoder-decoder blocks, similar to the conventionally used Unet, and with technical highlights of full-scale skip connections, deep supervision, and classification-guided module (CGM). In Huang et al. (2020), UNET 3+ overperformed Unet and Unet++ in the dataset of ISBI LiTS 2017 Challenge.
#
# We specify five downsampling blocks with the number of convolution filters grows from 32 to 512. Each downsampling level consists of two convolutional layers. The upsampling block of UNET 3+ features a full-scale skip connection of five input tensors, and each tensor is originated from a different down-/upsampling level. Within the upsampling block, each input tensor is processed by a convolutional layer with 32 filters ( `filter_num_skip=32` ), then concatenated, and passed through another convolutional layer with 160 filters ( `filter_num_aggregate=160` ). The resulting tensors are collected and fed into either the next upsampling block or the output section.
#
# The code cell below configures the base architecture of this segmentation model. The input size is fixed to 128-by-128. Batch normalization is applied after each of the convolutional layers. Down- and upsampling are achieved through maxpooling and bilinear interpolation, respectively.
#
# Further use case of `base.unet_3plus_2d_base` is available through its Python helper function:
#
# ```python
# from keras_unet_collection import models
#
# help(base.unet_3plus_2d_base)
# ```

# %%
name = 'unet3plus'
activation = 'ReLU'
#filter_num_down = [32, 64, 128, 256, 512]
filter_num_down = [16, 32, 144, 240, 672, 1152]
filter_num_skip = [32, 32, 32, 32, 32]
filter_num_aggregate = 160

stack_num_down = 2
stack_num_up = 1
n_labels = 3

# `unet_3plus_2d_base` accepts an input tensor 
# and produces output tensors from different upsampling levels
# ---------------------------------------- #
input_tensor = keras.layers.Input((128, 128, 3), batch_size=32)
# base architecture
X_decoder = models.unet_3plus_2d(
    (128, 128, 3), n_labels=n_labels, filter_num_down=filter_num_down, filter_num_skip=filter_num_skip, filter_num_aggregate=filter_num_aggregate, 
    backbone='hub://EfficientNet-lite0',
    #backbone='EfficientNetB0',
    deep_supervision=True,
    stack_num_down=stack_num_down, stack_num_up=stack_num_up, activation=activation, 
    batch_norm=True, pool=True, unpool=True, name=name)
# Out:
# EfficientNet-lite0
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 32), dtype=tf.float32, name=None), name='keras_layer/StatefulPartitionedCall:37', description="created by layer 'keras_layer'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 144), dtype=tf.float32, name=None), name='keras_layer/StatefulPartitionedCall:39', description="created by layer 'keras_layer'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 240), dtype=tf.float32, name=None), name='keras_layer/StatefulPartitionedCall:41', description="created by layer 'keras_layer'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 672), dtype=tf.float32, name=None), name='keras_layer/StatefulPartitionedCall:43', description="created by layer 'keras_layer'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 1152), dtype=tf.float32, name=None), name='keras_layer/StatefulPartitionedCall:45', description="created by layer 'keras_layer'")
# [<KerasTensor: shape=(None, 64, 64, 32) dtype=float32 (created by layer 'EfficientNet-lite0_backbone')>, <KerasTensor: shape=(None, 32, 32, 144) dtype=float32 (created by layer 'EfficientNet-lite0_backbone')>, <KerasTensor: shape=(None, 16, 16, 240) dtype=float32 (created by layer 'EfficientNet-lite0_backbone')>, <KerasTensor: shape=(None, 8, 8, 672) dtype=float32 (created by layer 'EfficientNet-lite0_backbone')>, <KerasTensor: shape=(None, 4, 4, 1152) dtype=float32 (created by layer 'EfficientNet-lite0_backbone')>] 6
# ----------
# deep_supervision = True
# names of output tensors are listed as follows ("sup0" is the shallowest supervision layer;
# "final" is the final output layer):
#
# 	unet3plus_output_sup0_activation
# 	unet3plus_output_sup1_activation
# 	unet3plus_output_sup2_activation
# 	unet3plus_output_sup3_activation
# 	unet3plus_output_sup4_activation
# 	unet3plus_output_final_activation

# %% [markdown]
# The collected feature maps as four-dimensional tensors of (sample number, width, height, channel) are shown as follows:

# %%
OUT_stack = X_decoder(input_tensor)
OUT_stack
# Out:
# [<KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>]

# %% [markdown]
# **Deep supervision**
#
# The output section of UNET 3+ consists of deep-supervision and Classification-Guided Module (CGM).
#
# Deep-supervision upsamples intermediate feature maps to full-resolution and enables the back-propagation of training loss from these full-resolution branches. Based on Huang et al. (2020). The deep-supervision branch of UNET 3+ consists of 3-by-3 convolutional layers followed by bilinear-interpolation-based upsampling and sigmoid output activation.
#
# The code cell below constructs deep-supervision branches. Alternatively, `keras_unet_collection.models.unet_3plus_2d` with `deep_supervision=True` would produce the same keras model.

# %% [markdown]
# The deep-supervision and final output tensors are shown as follows:

# %%
OUT_stack
# Out:
# [<KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'model')>]

# %% [markdown]
# **Classification-guided Module (CGM)**
#
# Huang et al. (2020) proposed CGM for handling the over-segmentation problem. CGM takes the output tensor of the deepest downsampling level, and converts it into a *single value* that indicates the probability of the existence of the segmentation target.
#
# The code cell below adds CGM into the existing deep-supervision branches.
#
# **Note**
#
# The CGM value is not trained separately in this example.
#
# In Huang et al. (2020), the CGM is trained with "none-organ images". This is not explicitly available in the Oxford-IIIT dataset.

# %%
# Classification-guided Module (CGM)
# ---------------------------------------- #
# dropout --> 1-by-1 conv2d --> global-maxpooling --> sigmoid
X_CGM = OUT_stack[-1]
X_CGM = Dropout(rate=0.1)(X_CGM)
X_CGM = Conv2D(filter_num_skip[-1], 1, padding='same')(X_CGM)
X_CGM = GlobalMaxPooling2D()(X_CGM)
X_CGM = Activation('sigmoid')(X_CGM)

CGM_mask = max(X_CGM, axis=-1) # <----- This value could be trained with "none-organ image"

for i in range(len(OUT_stack)):
    if i < len(OUT_stack)-1:
        # deep-supervision
        OUT_stack[i] = multiply([OUT_stack[i], CGM_mask], name='{}_output_sup{}_CGM'.format(name, i))
    else:
        # final output
        OUT_stack[i] = multiply([OUT_stack[i], CGM_mask], name='{}_output_final_CGM'.format(name))

# %%
OUT_stack
# Out:
# [<KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'unet3plus_output_sup0_CGM')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'unet3plus_output_sup1_CGM')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'unet3plus_output_sup2_CGM')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'unet3plus_output_sup3_CGM')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'unet3plus_output_sup4_CGM')>,
#  <KerasTensor: shape=(32, 128, 128, 3) dtype=float32 (created by layer 'unet3plus_output_final_CGM')>]

# %% [markdown]
# **Compiling the segmentation model**
#
# The segmentation model is trained with cross-entropy loss. Each deep-supervision branch contributes 12.5% of the total loss value, whereas the final output loss contribution is 50%. The Adam optimizer with a learning rate of 1E-4 is applied.

# %%
# executing all the above cells in one time to avoid dupilcated tensor names.
unet3plus = keras.models.Model([input_tensor,], OUT_stack)

# %% [markdown]
# **Hybrid loss**
#
# The hybrid loss function, as suggested in Huang et al. (2020) is implemented.
#
# **Note**
#
# * The MS-SSMI loss is found lack of robustness in training, likely becuase of the hard-labeled binary target.
#
# * The focal loss is replaced by the focal Tversky loss.

# %%
from keras_unet_collection import losses

def hybrid_loss(y_true, y_pred):

    loss_focal = losses.focal_tversky(y_true, y_pred, alpha=0.5, gamma=4/3)
    loss_iou = losses.iou_seg(y_true, y_pred)
    
    # (x) 
    #loss_ssim = losses.ms_ssim(y_true, y_pred, max_val=1.0, filter_size=4)
    
    return loss_focal+loss_iou #+loss_ssim

# %%
#hybrid_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=False, reduction= tf.keras.losses.Reduction.NONE)
hybrid_loss = hybrid_loss

# %% [markdown]
# This hybrid loss is applied for deep supervisions and the final pridction:

# %%
unet3plus.compile(loss=[hybrid_loss, hybrid_loss, hybrid_loss, hybrid_loss, hybrid_loss, hybrid_loss],
                  loss_weights=[0.25, 0.25, 0.25, 0.25, 0.25, 1.0],
                  optimizer=keras.optimizers.Adam(learning_rate=1e-4))

# %% [markdown]
# ## Data pre-processing
#
# The input of RGB images are resized to 128-by-128 through the nearest neighbour scheme, and then normalized to the interval of [0, 1]. The training target of pixel-wise masks are resized similarly.
#
# A random split is applied with 80%, 10%, 10% of the samples are assigned for training, validation, and testing, respectively.

# %%
import albumentations as albu

# %%
def get_training_augmentation(width=513, height=513):
    train_transform = [
        

        #albu.RandomRotate90(p=0.5),
        
        #albu.OneOf([
        #   
        #   
        #], p=1),
        albu.Resize(width, height, 2, p=1),

        albu.ShiftScaleRotate(shift_limit = 0.05, scale_limit=(0.1, 0.1), interpolation=2, rotate_limit=25, p=0.3),
        
        albu.HorizontalFlip(p=0.5),
        albu.VerticalFlip(p=0.15),


        albu.OneOf([
            albu.ISONoise(p=1),
            albu.MultiplicativeNoise(p=1),
            albu.GaussNoise(p=1),
            albu.ImageCompression(p=1),

        ], p=0.2),
        
        albu.Perspective(pad_mode=2, p=0.1),

        albu.OneOf(
            [
                albu.CLAHE(p=1),
                albu.RandomBrightnessContrast(p=1),
                albu.Sharpen(p=1),
                albu.Emboss(p=1),
                albu.RandomGamma(p=1),
            ],
            p=0.5,
        ),

        albu.OneOf(
            [
                albu.Blur(blur_limit=5, p=1),
                albu.MedianBlur(blur_limit=5, p=1),
                albu.MotionBlur(blur_limit=5, p=1),
            ],
            p=0.25,
        ),

        albu.OneOf(
            [
                albu.RandomBrightnessContrast(p=1),
                albu.HueSaturationValue(p=1),
                albu.RGBShift(p=1),
            ],
            p=0.25,
        ),
        
        albu.OneOf(
            [
                #albu.ElasticTransform(alpha=10, sigma=10 * 0.05, alpha_affine=10 * 0.03, p=0.5),
                albu.GridDistortion(p=0.5),
                albu.OpticalDistortion(distort_limit=0.3, shift_limit=0.05, p=1)      
            ],
            p=0.25,
        ),
    ]
    
    return albu.Compose(train_transform)

# %%
from keras_unet_collection.dataset_utils import SegmentationAlbumentationsDataLoader
# Out:
# WARNING:matplotlib:Matplotlib created a temporary config/cache directory at /tmp/matplotlib-b3lzwk6b because the default path (/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
loader = SegmentationAlbumentationsDataLoader(num_classes=3, batch_size=32, width=128, height=128, dataset_path=filepath, train_augmentations=get_training_augmentation(128, 128), masks_dir='annotations/trimaps', label_shift=1)
# Out:
# Train Images are good to go

# %%
train_set, val_set, test_set = loader.build_datasets()

# %%
loader.show_images(16)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def input_data_process(input_array):
    '''converting pixel vales to [0, 1]'''
    return input_array/255.

def target_data_process(target_array):
    '''Converting tri-mask of {1, 2, 3} to three categories.'''
    return keras.utils.to_categorical(target_array-1)

# %%
sample_names = np.array(sorted(glob(filepath+'images/*.jpg')))
label_names = np.array(sorted(glob(filepath+'annotations/trimaps/*.png')))

L = len(sample_names)
ind_all = utils.shuffle_ind(L)

L_train = int(0.8*L); L_valid = int(0.1*L); L_test = L - L_train - L_valid
ind_train = ind_all[:L_train]; ind_valid = ind_all[L_train:L_train+L_valid]; ind_test = ind_all[L_train+L_valid:]
print("Training:validation:testing = {}:{}:{}".format(L_train, L_valid, L_test))
# Out:
# Training:validation:testing = 5909:738:740

# %%
valid_input = input_data_process(utils.image_to_array(sample_names[ind_valid], size=128, channel=3))
valid_target = target_data_process(utils.image_to_array(label_names[ind_valid], size=128, channel=1))

# %%
test_input = input_data_process(utils.image_to_array(sample_names[ind_test], size=128, channel=3))
test_target = target_data_process(utils.image_to_array(label_names[ind_test], size=128, channel=1))

# %% [markdown]
# ## Training
#
# The segmentation model is trained with fixed 10 epoches. Each epoch containts 100 batches and each batch contains 32 samples.
#
# *The training process here is far from systematic, and is provided for illustration purposes only.*

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("unet_segmentation.h5", save_best_only=True)
]


model_history = unet3plus.fit(train_set, epochs=100,
                          #steps_per_epoch=STEPS_PER_EPOCH,
                          #validation_steps=VALIDATION_STEPS,
                          validation_data=val_set,
                          callbacks=callbacks)
# Out:
# Epoch 1/100
# 184/184 [==============================] - 49s 213ms/step - loss: 2.2040 - unet3plus_output_sup0_CGM_loss: 0.9534 - unet3plus_output_sup1_CGM_loss: 0.9770 - unet3plus_output_sup2_CGM_loss: 1.0276 - unet3plus_output_sup3_CGM_loss: 1.0650 - unet3plus_output_sup4_CGM_loss: 1.1850 - unet3plus_output_final_CGM_loss: 0.9020 - val_loss: 2.1166 - val_unet3plus_output_sup0_CGM_loss: 0.8952 - val_unet3plus_output_sup1_CGM_loss: 0.9401 - val_unet3plus_output_sup2_CGM_loss: 0.9767 - val_unet3plus_output_sup3_CGM_loss: 0.9869 - val_unet3plus_output_sup4_CGM_loss: 1.1470 - val_unet3plus_output_final_CGM_loss: 0.8801
# /usr/local/lib/python3.6/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
#
# Epoch 56/100
# 184/184 [==============================] - 39s 209ms/step - loss: 0.9168 - unet3plus_output_sup0_CGM_loss: 0.3162 - unet3plus_output_sup1_CGM_loss: 0.3347 - unet3plus_output_sup2_CGM_loss: 0.3873 - unet3plus_output_sup3_CGM_loss: 0.4958 - unet3plus_output_sup4_CGM_loss: 0.8786 - unet3plus_output_final_CGM_loss: 0.3136 - val_loss: 0.9076 - val_unet3plus_output_sup0_CGM_loss: 0.3151 - val_unet3plus_output_sup1_CGM_loss: 0.3312 - val_unet3plus_output_sup2_CGM_loss: 0.3833 - val_unet3plus_output_sup3_CGM_loss: 0.4866 - val_unet3plus_output_sup4_CGM_loss: 0.8627 - val_unet3plus_output_final_CGM_loss: 0.3129
# Epoch 57/100
#  18/184 [=>............................] - ETA: 33s - loss: 0.9149 - unet3plus_output_sup0_CGM_loss: 0.3147 - unet3plus_output_sup1_CGM_loss: 0.3336 - unet3plus_output_sup2_CGM_loss: 0.3871 - unet3plus_output_sup3_CGM_loss: 0.4975 - unet3plus_output_sup4_CGM_loss: 0.8780 - unet3plus_output_final_CGM_loss: 0.3122
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-792818cd94cf> in <module>
#       8                           #validation_steps=VALIDATION_STEPS,
#       9                           validation_data=val_set,
# ---> 10                           callbacks=callbacks)
#
# ~usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187               logs = tmp_logs  # No error, now safe to assign to logs.
#    1188               end_step = step + data_handler.step_increment
# -> 1189               callbacks.on_train_batch_end(end_step, logs)
#    1190               if self.stop_training:
#    1191                 break
#
# ~usr/local/lib/python3.6/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_train_batch_hooks:
# --> 435       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     436
#     437   def on_test_batch_begin(self, batch, logs=None):
#
# ~usr/local/lib/python3.6/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# ~usr/local/lib/python3.6/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     313       self._batch_times.append(batch_time)
#     314
# --> 315     self._call_batch_hook_helper(hook_name, batch, logs)
#     316
#     317     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~usr/local/lib/python3.6/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351     for callback in self.callbacks:
#     352       hook = getattr(callback, hook_name)
# --> 353       hook(batch, logs)
#     354
#     355     if self._check_timing:
#
# ~usr/local/lib/python3.6/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1026
#    1027   def on_train_batch_end(self, batch, logs=None):
# -> 1028     self._batch_update_progbar(batch, logs)
#    1029
#    1030   def on_test_batch_end(self, batch, logs=None):
#
# ~usr/local/lib/python3.6/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1098     if self.verbose == 1:
#    1099       # Only block async when verbose = 1.
# -> 1100       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1102
#
# ~usr/local/lib/python3.6/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~usr/local/lib/python3.6/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     510   def _to_single_numpy_or_python_type(t):
#     511     if isinstance(t, tf.Tensor):
# --> 512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
for i in range(1000):
    for j in train_set:
        pass

# %%
data = train_set.__iter__().next()[0]
print(len(data))
res = unet3plus.predict(data)
print(len(res[4]))

# %% [markdown]
# ## Evaluation
#
# The testing set performance is evaluated.

# %%
temp_out = unet3plus.predict([test_input[:],])
y_pred = temp_out[-1]

# %%
print('Testing set cross-entropy loss = {}'.format(np.mean(keras.losses.categorical_crossentropy(test_target[:], y_pred))))
print('Testing set focal Tversky loss = {}'.format(np.mean(losses.focal_tversky(test_target[:], y_pred))))
print('Testing set IoU loss = {}'.format(np.mean(losses.iou_seg(test_target[:], y_pred))))
# Out:
# Testing set cross-entropy loss = 1.001997947692871
# Testing set focal Tversky loss = 0.16268157958984375
# Testing set IoU loss = 0.1631283164024353

# %% [markdown]
# **Example of outputs**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def ax_decorate_box(ax):
    [j.set_linewidth(0) for j in ax.spines.values()]
    ax.tick_params(axis="both", which="both", bottom=False, top=False, 
                   labelbottom=False, left=False, right=False, labelleft=False)
    return ax

# %%
i_sample = 10

fig, AX = plt.subplots(2, 5, figsize=(13, (26-0.2)/4))
plt.subplots_adjust(0, 0, 1, 1, hspace=0, wspace=0.1)
for ax in AX[0]:
    ax = ax_decorate_box(ax)
for ax in AX[1]:
    ax = ax_decorate_box(ax)    
AX[0][0].pcolormesh(np.mean(test_input[i_sample, ...,], axis=-1), cmap=plt.cm.gray)
AX[0][1].pcolormesh(y_pred[i_sample, ..., 0], cmap=plt.cm.jet)
AX[0][2].pcolormesh(y_pred[i_sample, ..., 1], cmap=plt.cm.jet)
AX[0][3].pcolormesh(y_pred[i_sample, ..., 2], cmap=plt.cm.jet)
AX[0][4].pcolormesh(np.argmax(y_pred[i_sample, ...], axis=2), cmap=plt.cm.jet)

AX[0][0].set_title("Original", fontsize=14);
AX[0][1].set_title("Pixels belong to the object", fontsize=14);
AX[0][2].set_title("Surrounding pixels", fontsize=14);
AX[0][3].set_title("Bordering pixels", fontsize=14);

AX[1][0].pcolormesh(np.mean(test_input[i_sample, ...,], axis=-1), cmap=plt.cm.gray)
AX[1][1].pcolormesh(test_target[i_sample, ..., 0], cmap=plt.cm.jet)
AX[1][2].pcolormesh(test_target[i_sample, ..., 1], cmap=plt.cm.jet)
AX[1][3].pcolormesh(test_target[i_sample, ..., 2], cmap=plt.cm.jet)
AX[1][4].pcolormesh(np.argmax(test_target[i_sample, ...], axis=2), cmap=plt.cm.jet)

# %% [markdown]
# ## Discussion
#
# A segmentation model is proposed based on the architecture of UNET 3+ and is trained using the Oxford-IIIT Pets dataset. Evaluation result indicates that this segmentation model can distinguish pixes of a pet from its backgrounds.
#
# Many technical details of this work, e.g., network hyper-parameters and training strategy, can be improved for achieving better performance.

# %% [markdown]
# **Reference**
#
# * Parkhi, O.M., Vedaldi, A., Zisserman, A. and Jawahar, C.V., 2012. Cats and dogs. In 2012 IEEE conference on computer vision and pattern recognition (pp. 3498-3505). IEEE.
#
# * Huang, H., Lin, L., Tong, R., Hu, H., Zhang, Q., Iwamoto, Y., Han, X., Chen, Y.W. and Wu, J., 2020. UNet 3+: A Full-Scale Connected UNet for Medical Image Segmentation. In ICASSP 2020-2020 IEEE International Conference on Acoustics, Speech and Signal Processing (ICASSP) (pp. 1055-1059). IEEE.

# %%
import tensorflow as tf

# %%
unet3plus.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(16, 128, 128, 3)]  0
# __________________________________________________________________________________________________
# EfficientNet-lite0_backbone (Fu [(16, 64, 64, 32), ( 3413024     input_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_up_0_en0_unpool (UpSa (16, 16, 16, 672)    0           EfficientNet-lite0_backbone[0][3]
# __________________________________________________________________________________________________
# unet3plus_down_0_en2_maxpool (M (16, 16, 16, 144)    0           EfficientNet-lite0_backbone[0][1]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to0_0 (Con (16, 16, 16, 32)     193536      unet3plus_up_0_en0_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to1_0 (Con (16, 16, 16, 32)     69120       EfficientNet-lite0_backbone[0][2]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to2_0 (Con (16, 16, 16, 32)     41472       unet3plus_down_0_en2_maxpool[0][0
# __________________________________________________________________________________________________
# unet3plus_down_from0_to0_0_bn ( (16, 16, 16, 32)     128         unet3plus_down_from0_to0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to1_0_bn ( (16, 16, 16, 32)     128         unet3plus_down_from0_to1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to2_0_bn ( (16, 16, 16, 32)     128         unet3plus_down_from0_to2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to0_0_acti (16, 16, 16, 32)     0           unet3plus_down_from0_to0_0_bn[0][
# __________________________________________________________________________________________________
# unet3plus_down_from0_to1_0_acti (16, 16, 16, 32)     0           unet3plus_down_from0_to1_0_bn[0][
# __________________________________________________________________________________________________
# unet3plus_down_from0_to2_0_acti (16, 16, 16, 32)     0           unet3plus_down_from0_to2_0_bn[0][
# __________________________________________________________________________________________________
# unet3plus_concat_0 (Concatenate (16, 16, 16, 96)     0           unet3plus_down_from0_to0_0_activa
#                                                                  unet3plus_down_from0_to1_0_activa
#                                                                  unet3plus_down_from0_to2_0_activa
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_0 (Conv (16, 16, 16, 160)    138240      unet3plus_concat_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_0_bn (B (16, 16, 16, 160)    640         unet3plus_fusion_conv_0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_0_activ (16, 16, 16, 160)    0           unet3plus_fusion_conv_0_0_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_up_1_en0_unpool (UpSa (16, 32, 32, 672)    0           EfficientNet-lite0_backbone[0][3]
# __________________________________________________________________________________________________
# unet3plus_up_1_en1_unpool (UpSa (16, 32, 32, 160)    0           unet3plus_fusion_conv_0_0_activat
# __________________________________________________________________________________________________
# unet3plus_down_from1_to0_0 (Con (16, 32, 32, 32)     193536      unet3plus_up_1_en0_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to1_0 (Con (16, 32, 32, 32)     46080       unet3plus_up_1_en1_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to2_0 (Con (16, 32, 32, 32)     41472       EfficientNet-lite0_backbone[0][1]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to0_0_bn ( (16, 32, 32, 32)     128         unet3plus_down_from1_to0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to1_0_bn ( (16, 32, 32, 32)     128         unet3plus_down_from1_to1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to2_0_bn ( (16, 32, 32, 32)     128         unet3plus_down_from1_to2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to0_0_acti (16, 32, 32, 32)     0           unet3plus_down_from1_to0_0_bn[0][
# __________________________________________________________________________________________________
# unet3plus_down_from1_to1_0_acti (16, 32, 32, 32)     0           unet3plus_down_from1_to1_0_bn[0][
# __________________________________________________________________________________________________
# unet3plus_down_from1_to2_0_acti (16, 32, 32, 32)     0           unet3plus_down_from1_to2_0_bn[0][
# __________________________________________________________________________________________________
# unet3plus_concat_1 (Concatenate (16, 32, 32, 96)     0           unet3plus_down_from1_to0_0_activa
#                                                                  unet3plus_down_from1_to1_0_activa
#                                                                  unet3plus_down_from1_to2_0_activa
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_0 (Conv (16, 32, 32, 160)    138240      unet3plus_concat_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_0_bn (B (16, 32, 32, 160)    640         unet3plus_fusion_conv_1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_0_activ (16, 32, 32, 160)    0           unet3plus_fusion_conv_1_0_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_up_2_en0_unpool (UpSa (16, 64, 64, 672)    0           EfficientNet-lite0_backbone[0][3]
# __________________________________________________________________________________________________
# unet3plus_up_2_en1_unpool (UpSa (16, 64, 64, 160)    0           unet3plus_fusion_conv_0_0_activat
# __________________________________________________________________________________________________
# unet3plus_up_2_en2_unpool (UpSa (16, 64, 64, 160)    0           unet3plus_fusion_conv_1_0_activat
# __________________________________________________________________________________________________
# unet3plus_down_from2_to0_0 (Con (16, 64, 64, 32)     193536      unet3plus_up_2_en0_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to1_0 (Con (16, 64, 64, 32)     46080       unet3plus_up_2_en1_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to2_0 (Con (16, 64, 64, 32)     46080       unet3plus_up_2_en2_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to0_0_bn ( (16, 64, 64, 32)     128         unet3plus_down_from2_to0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to1_0_bn ( (16, 64, 64, 32)     128         unet3plus_down_from2_to1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to2_0_bn ( (16, 64, 64, 32)     128         unet3plus_down_from2_to2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to0_0_acti (16, 64, 64, 32)     0           unet3plus_down_from2_to0_0_bn[0][
# __________________________________________________________________________________________________
# unet3plus_down_from2_to1_0_acti (16, 64, 64, 32)     0           unet3plus_down_from2_to1_0_bn[0][
# __________________________________________________________________________________________________
# unet3plus_down_from2_to2_0_acti (16, 64, 64, 32)     0           unet3plus_down_from2_to2_0_bn[0][
# __________________________________________________________________________________________________
# unet3plus_concat_2 (Concatenate (16, 64, 64, 96)     0           unet3plus_down_from2_to0_0_activa
#                                                                  unet3plus_down_from2_to1_0_activa
#                                                                  unet3plus_down_from2_to2_0_activa
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_0 (Conv (16, 64, 64, 160)    138240      unet3plus_concat_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_0_bn (B (16, 64, 64, 160)    640         unet3plus_fusion_conv_2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_0_activ (16, 64, 64, 160)    0           unet3plus_fusion_conv_2_0_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_plain_up3_decode_unpo (16, 128, 128, 160)  0           unet3plus_fusion_conv_2_0_activat
# __________________________________________________________________________________________________
# unet3plus_plain_up3_conv_before (16, 128, 128, 160)  230400      unet3plus_plain_up3_decode_unpool
# __________________________________________________________________________________________________
# unet3plus_plain_up3_conv_before (16, 128, 128, 160)  640         unet3plus_plain_up3_conv_before_c
# __________________________________________________________________________________________________
# unet3plus_plain_up3_conv_before (16, 128, 128, 160)  0           unet3plus_plain_up3_conv_before_c
# __________________________________________________________________________________________________
# dropout (Dropout)               (16, 8, 8, 672)      0           EfficientNet-lite0_backbone[0][3]
# __________________________________________________________________________________________________
# unet3plus_plain_up3_conv_after_ (16, 128, 128, 160)  230400      unet3plus_plain_up3_conv_before_c
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (16, 8, 8, 32)       21536       dropout[0][0]
# __________________________________________________________________________________________________
# unet3plus_plain_up3_conv_after_ (16, 128, 128, 160)  640         unet3plus_plain_up3_conv_after_co
# __________________________________________________________________________________________________
# unet3plus_output_conv1_0 (Conv2 (16, 64, 64, 3)      4323        unet3plus_fusion_conv_2_0_activat
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (16, 32)             0           conv2d[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_conv1_1 (Conv2 (16, 32, 32, 3)      4323        unet3plus_fusion_conv_1_0_activat
# __________________________________________________________________________________________________
# unet3plus_output_conv1_2 (Conv2 (16, 16, 16, 3)      4323        unet3plus_fusion_conv_0_0_activat
# __________________________________________________________________________________________________
# unet3plus_output_conv1_3 (Conv2 (16, 8, 8, 3)        18147       EfficientNet-lite0_backbone[0][3]
# __________________________________________________________________________________________________
# unet3plus_plain_up3_conv_after_ (16, 128, 128, 160)  0           unet3plus_plain_up3_conv_after_co
# __________________________________________________________________________________________________
# unet3plus_output_sup0 (UpSampli (16, 128, 128, 3)    0           unet3plus_output_conv1_0[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (16, 32)             0           global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup1 (UpSampli (16, 128, 128, 3)    0           unet3plus_output_conv1_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup2 (UpSampli (16, 128, 128, 3)    0           unet3plus_output_conv1_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup3 (UpSampli (16, 128, 128, 3)    0           unet3plus_output_conv1_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_final (Conv2D) (16, 128, 128, 3)    4323        unet3plus_plain_up3_conv_after_co
# __________________________________________________________________________________________________
# unet3plus_output_sup0_activatio (16, 128, 128, 3)    0           unet3plus_output_sup0[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max (TFOpLambda) (16,)                0           activation[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup1_activatio (16, 128, 128, 3)    0           unet3plus_output_sup1[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup2_activatio (16, 128, 128, 3)    0           unet3plus_output_sup2[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup3_activatio (16, 128, 128, 3)    0           unet3plus_output_sup3[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_final_activati (16, 128, 128, 3)    0           unet3plus_output_final[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup0_CGM (Mult (16, 128, 128, 3)    0           unet3plus_output_sup0_activation[
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup1_CGM (Mult (16, 128, 128, 3)    0           unet3plus_output_sup1_activation[
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup2_CGM (Mult (16, 128, 128, 3)    0           unet3plus_output_sup2_activation[
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_sup3_CGM (Mult (16, 128, 128, 3)    0           unet3plus_output_sup3_activation[
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# unet3plus_output_final_CGM (Mul (16, 128, 128, 3)    0           unet3plus_output_final_activation
#                                                                  tf.math.reduce_max[0][0]
# ==================================================================================================
# Total params: 5,220,783
# Trainable params: 1,805,583
# Non-trainable params: 3,415,200
# __________________________________________________________________________________________________

# %%
def representative_data_gen():
    for input_value in tf.data.Dataset.from_tensor_slices(test_input).batch(1).take(1):
        yield [tf.cast(input_value, tf.float32) /255.]

converter = tf.lite.TFLiteConverter.from_saved_model("modello243")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
# Ensure that if any ops can't be quantized, the converter throws an error
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# Set the input and output tensors to uint8 (APIs added in r2.3)
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8

tflite_ui8_model = converter.convert()
# Out:
# WARNING:absl:For model inputs containing unsupported operations which cannot be quantized, the `inference_input_type` attribute will default to the original type.

# %%
# Save the f16 model.
with open('model_260_ui8.tflite', 'wb') as f:
  f.write(tflite_ui8_model)

# %%
import tensorflow as tf

# %%
input_static=tf.keras.layers.Input((512, 512,3), dtype=tf.float32, batch_size=1)

# %%
input_static
# Out:
# <KerasTensor: shape=(1, 128, 128, 3) dtype=float32 (created by layer 'input_2')>

# %%
unet3plus2 = keras.models.Model(input_static, OUT_stack[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-31d7f0dc0687> in <module>
# ----> 1 unet3plus2 = keras.models.Model(input_static, OUT_stack[0])
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     520     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521     try:
# --> 522       result = method(self, *args, **kwargs)
#     523     finally:
#     524       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/functional.py in __init__(self, inputs, outputs, name, trainable, **kwargs)
#     113     generic_utils.validate_kwargs(kwargs, {})
#     114     super(Functional, self).__init__(name=name, trainable=trainable)
# --> 115     self._init_graph_network(inputs, outputs)
#     116
#     117   @trackable.no_automatic_dependency_tracking
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     520     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521     try:
# --> 522       result = method(self, *args, **kwargs)
#     523     finally:
#     524       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/functional.py in _init_graph_network(self, inputs, outputs)
#     196
#     197     # Keep track of the network's nodes and layers.
# --> 198     nodes, nodes_by_depth, layers, _ = _map_graph_network(
#     199         self.inputs, self.outputs)
#     200     self._network_nodes = nodes
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/functional.py in _map_graph_network(inputs, outputs)
#     983         for x in nest.flatten(node.keras_inputs):
#     984           if id(x) not in computable_tensors:
# --> 985             raise ValueError('Graph disconnected: '
#     986                              'cannot obtain value for tensor ' + str(x) +
#     987                              ' at layer "' + layer.name + '". '
#
# ValueError: Graph disconnected: cannot obtain value for tensor KerasTensor(type_spec=TensorSpec(shape=(1, 128, 128, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'") at layer "unet3plus_down0_0". The following previous layers were accessed without issue: []

# %%
import tensorflow_hub as hub

# %%
backbone_ = hub.KerasLayer('https://tfhub.dev/tensorflow/efficientnet/lite0/feature-vector/2', input_shape=(513, 513, 3), signature='image_feature_vector', signature_outputs_as_dict=True, trainable=False)

# %%
res = backbone_(input_static)

# %%
sorted(res)
# Out:
# ['block_0',
#  'block_0/expansion_output',
#  'block_1',
#  'block_1/expansion_output',
#  'block_10',
#  'block_10/expansion_output',
#  'block_11',
#  'block_11/expansion_output',
#  'block_12',
#  'block_12/expansion_output',
#  'block_13',
#  'block_13/expansion_output',
#  'block_14',
#  'block_14/expansion_output',
#  'block_15',
#  'block_15/expansion_output',
#  'block_2',
#  'block_2/expansion_output',
#  'block_3',
#  'block_3/expansion_output',
#  'block_4',
#  'block_4/expansion_output',
#  'block_5',
#  'block_5/expansion_output',
#  'block_6',
#  'block_6/expansion_output',
#  'block_7',
#  'block_7/expansion_output',
#  'block_8',
#  'block_8/expansion_output',
#  'block_9',
#  'block_9/expansion_output',
#  'default',
#  'features',
#  'head_1x1',
#  'pooled_features',
#  'reduction_1',
#  'reduction_1/expansion_output',
#  'reduction_2',
#  'reduction_2/expansion_output',
#  'reduction_3',
#  'reduction_3/expansion_output',
#  'reduction_4',
#  'reduction_4/expansion_output',
#  'reduction_5',
#  'reduction_5/expansion_output',
#  'stem']

# %%
res['reduction_5/expansion_output']
# Out:
# <KerasTensor: shape=(1, 16, 16, 1152) dtype=float32 (created by layer 'keras_layer')>

# %%
res['reduction_5']
# Out:
# <KerasTensor: shape=(1, 16, 16, 320) dtype=float32 (created by layer 'keras_layer')>
